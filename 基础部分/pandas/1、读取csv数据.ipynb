# %%
import pandas as pd

# %%
df=pd.read_csv("/root/workspace/pandas/healthcare-dataset-stroke-data.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0           0.0            1.0          Yes
# 1     51676  Female  61.0           0.0            0.0          Yes
# 2     31112    Male  80.0           0.0            1.0          Yes
# 3     60182  Female  49.0           0.0            0.0          Yes
# 4      1665  Female  79.0           1.0            0.0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 4920  18234  Female  80.0           1.0            0.0          Yes
# 4921  44873  Female  81.0           0.0            0.0          Yes
# 4922  19723  Female  35.0           0.0            0.0          Yes
# 4923  37544    Male  51.0           0.0            0.0          Yes
# 4924  44679  Female  44.0           0.0            0.0          Yes
#
#           work_type Residence_type  avg_glucose_level      bmi  \
# 0           Private          Urban             228.69     36.6
# ...

# %%
len(df)
df.columns
df[["gender","age"]]
# Out:
#       gender   age
# 0       Male  67.0
# 1     Female  61.0
# 2       Male  80.0
# 3     Female  49.0
# 4     Female  79.0
# ...      ...   ...
# 4920  Female  80.0
# 4921  Female  81.0
# 4922  Female  35.0
# 4923    Male  51.0
# 4924  Female  44.0
#
# [4925 rows x 2 columns]

# %%
df.iloc[1:3]
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 1  51676  Female  61.0           0.0            0.0          Yes
# 2  31112    Male  80.0           0.0            1.0          Yes
#
#        work_type Residence_type  avg_glucose_level      bmi smoking_status  \
# 1  Self-employed          Rural             202.21  Unknown   never smoked
# 2        Private          Rural             105.92     32.5   never smoked
#
#    stroke
# 1     1.0
# 2     1.0

# %%
df.iloc[1:3]["gender"]
# Out:
# 1    Female
# 2      Male
# Name: gender, dtype: object

# %%
df=df.drop_duplicates() # 去重
len(df)
# Out:
# 4920

# %%
df=df.drop_duplicates(["gender","age"]) # 根据列去重
len(df)
# Out:
# 208

# %%
df[df["age"]==23] #取值
# df[pd.isna(df["age"])] # 找空值
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 286   36811  Female  23.0           0.0            0.0           No   Private
# 343    9487  Female  23.0           0.0            0.0           No   Private
# 372   34402  Female  23.0           0.0            0.0          Yes   Private
# 524   41800  Female  23.0           0.0            0.0          Yes   Private
# 527    5374    Male  23.0           0.0            0.0           No   Private
# ...     ...     ...   ...           ...            ...          ...       ...
# 4549  45922  Female  23.0           0.0            0.0           No   Private
# 4558   8111  Female  23.0           0.0            0.0           No   Private
# 4568  17130  Female  23.0           0.0            0.0           No   Private
# 4745  27804    Male  23.0           0.0            0.0           No   Private
# 4778  59945  Female  23.0           0.0            0.0           No   Private
#
# ...

# %%
# 平均值、标准差、最大值、最小值、中位数
df["age"].mean()
# Out:
# 43.30426975421491
